# %%
import pandas as pd

# %%
A= pd.read_csv('customers.csv')
print(A)
# Out:
#        1   Leslie      Bass  F  27  B  37307        endslost@everyma1l.org  \
# 0      2     Judy     Burks  M  53  S  84759        rfleming@hotma1l.co.uk
# 1      3   Marsha     Doyle  F  48  B  80932          arethe53@ma1lbox.net
# 2      4   Alexis    Battle  M  27  S  71701            ofcame@ma1lbox.org
# 3      5   Martha     Combs  F  49  B  83947         camedied@everyma1l.us
# 4      6  Marilyn    Nguyen  M  57  S  72274    discoveredlist82@gma1l.org
# ..   ...      ...       ... ..  .. ..    ...                           ...
# 994  964    Jared  McDowell  M  57  S  81891    rescueship@everyma1l.co.uk
# 995  965     Rita    Bender  F  46  B  57356             itlost@ma1l2u.biz
# 996  966    Myron     Blake  M  46  S  82675  librarysmoke@everyma1l.co.uk
# 997  967     Tina   Sargent  F  60  B  32097          mhanson@somema1l.com
# 998  968    Paula     Young  M  32  S  23603       lostwhite12@b1zmail.net
#
# ...

# %%
path = 'customers.csv'
customer = pd.read_csv(path, header=None, names = ['custno','firstname','lastname','gender','age','profession','contactNo','emailId','city','state','isActive','createdDate','UpdatedDate'])
customer.to_csv(path,  index=False)

# %%
print(customer)
# Out:
#      custno firstname  lastname gender  age profession  contactNo  \
# 0         1    Leslie      Bass      F   27          B      37307
# 1         2      Judy     Burks      M   53          S      84759
# 2         3    Marsha     Doyle      F   48          B      80932
# 3         4    Alexis    Battle      M   27          S      71701
# 4         5    Martha     Combs      F   49          B      83947
# ..      ...       ...       ...    ...  ...        ...        ...
# 995     964     Jared  McDowell      M   57          S      81891
# 996     965      Rita    Bender      F   46          B      57356
# 997     966     Myron     Blake      M   46          S      82675
# 998     967      Tina   Sargent      F   60          B      32097
# 999     968     Paula     Young      M   32          S      23603
#
#                           emailId        city        state isActive  \
# 0          endslost@everyma1l.org      Gibson     Dellwood        Y
# ...

# %%
import pandas as pd
path = 'products.csv'
product = pd.read_csv(path, header=None,names=['productno', 'productName', 'Description', 'isActive', 'createdDate', 'UpdatedDate'])
product.to_csv(path, index=False)

# %%
print(product)
# Out:
#      productno  productName Description isActive          createdDate  \
# 0            1     Product1  pgqorighfa        Y  2017-04-03 07:58:55
# 1            2     Product2  lmndaaweth        Y  2017-09-21 12:38:31
# 2            3     Product3  urifeubrhh        Y  2017-09-08 10:32:12
# 3            4     Product4  rlpcjxfarp        Y  2017-05-22 05:29:27
# 4            5     Product5  hzcpozsgfc        Y  2017-02-02 08:40:29
# ..         ...          ...         ...      ...                  ...
# 995        996   Product996  acvxzpvhyu        Y  2017-09-09 07:49:14
# 996        997   Product997  eguyggimfm        Y  2017-09-14 12:13:29
# 997        998   Product998  hagbslxugf        Y  2017-04-20 06:25:03
# 998        999   Product999  iuoraxdrlf        Y  2017-03-06 05:00:08
# 999       1000  Product1000  ewgaacrkht        N  2017-07-13 02:52:44
#
#              UpdatedDate
# 0    2017-10-18 12:12:38
# 1    2017-10-18 12:12:38
# 2    2017-10-18 12:12:38
# ...

# %%
path = 'transactions.csv'
transaction = pd.read_csv(path , header= None, names = ['txnno','txndate','custno','amount','productno','spendby'])
transaction.to_csv(path, index=False)

# %%
m1=pd.merge(customer,transaction)
print(m1)
# Out:
#      custno firstname  lastname gender  age profession  contactNo  \
# 0         2      Judy     Burks      M   53          S      84759
# 1         2      Judy     Burks      M   53          S      84759
# 2         3    Marsha     Doyle      F   48          B      80932
# 3         4    Alexis    Battle      M   27          S      71701
# 4         4    Alexis    Battle      M   27          S      71701
# ..      ...       ...       ...    ...  ...        ...        ...
# 995     964     Jared  McDowell      M   57          S      81891
# 996     965      Rita    Bender      F   46          B      57356
# 997     965      Rita    Bender      F   46          B      57356
# 998     966     Myron     Blake      M   46          S      82675
# 999     967      Tina   Sargent      F   60          B      32097
#
#                           emailId        city        state isActive  \
# 0          rfleming@hotma1l.co.uk     Suwanee       Trabue        Y
# ...

# %%
print(transaction)
# Out:
#      txnno              txndate  custno  amount  productno spendby
# 0        1  2017-10-18 12:31:45     923    2559        376    Card
# 1        2  2017-10-18 12:31:45     219    1706        151    Card
# 2        3  2017-10-18 12:31:45     927    3462        707    Cash
# 3        4  2017-10-18 12:31:45     806     865        539    Card
# 4        5  2017-10-18 12:31:45     958    2494         25    Card
# ..     ...                  ...     ...     ...        ...     ...
# 995    996  2017-10-18 12:31:46     653    2872        155    Cash
# 996    997  2017-10-18 12:31:46     849     815        386    Card
# 997    998  2017-10-18 12:31:46     939    3932        529    Card
# 998    999  2017-10-18 12:31:46     547    3021        774    Cash
# 999   1000  2017-10-18 12:31:46     204    2314        828    Card
#
# [1000 rows x 6 columns]

# %%
# Usecase-1 Load all three csv datasets in Pandas Data frames and display first 5 records.
print(customer.head())
# Out:
#    custno firstname lastname gender  age profession  contactNo  \
# 0       1    Leslie     Bass      F   27          B      37307
# 1       2      Judy    Burks      M   53          S      84759
# 2       3    Marsha    Doyle      F   48          B      80932
# 3       4    Alexis   Battle      M   27          S      71701
# 4       5    Martha    Combs      F   49          B      83947
#
#                   emailId     city      state isActive          createdDate  \
# 0  endslost@everyma1l.org   Gibson   Dellwood        Y  2017-09-21 12:38:22
# 1  rfleming@hotma1l.co.uk  Suwanee     Trabue        Y  2017-05-22 05:29:22
# 2    arethe53@ma1lbox.net    Perry  Moxadarla        Y  2017-09-03 12:11:29
# 3      ofcame@ma1lbox.org   Morven     Dennis        Y  2017-02-16 04:05:35
# 4   camedied@everyma1l.us   Ocilla  Greenwood        Y  2017-05-15 07:34:35
#
#            UpdatedDate
# 0  2017-10-18 12:12:28
# 1  2017-10-18 12:12:28
# 2  2017-10-18 12:12:28
# 3  2017-10-18 12:12:28
# ...

# %%
print(product.head())
# Out:
#    productno productName Description isActive          createdDate  \
# 0          1    Product1  pgqorighfa        Y  2017-04-03 07:58:55
# 1          2    Product2  lmndaaweth        Y  2017-09-21 12:38:31
# 2          3    Product3  urifeubrhh        Y  2017-09-08 10:32:12
# 3          4    Product4  rlpcjxfarp        Y  2017-05-22 05:29:27
# 4          5    Product5  hzcpozsgfc        Y  2017-02-02 08:40:29
#
#            UpdatedDate
# 0  2017-10-18 12:12:38
# 1  2017-10-18 12:12:38
# 2  2017-10-18 12:12:38
# 3  2017-10-18 12:12:38
# 4  2017-10-18 12:12:38

# %%
print(transaction.head())
# Out:
#    txnno              txndate  custno  amount  productno spendby
# 0      1  2017-10-18 12:31:45     923    2559        376    Card
# 1      2  2017-10-18 12:31:45     219    1706        151    Card
# 2      3  2017-10-18 12:31:45     927    3462        707    Cash
# 3      4  2017-10-18 12:31:45     806     865        539    Card
# 4      5  2017-10-18 12:31:45     958    2494         25    Card

# %%
# Usecase-2 Display only those customers from CSV_s1, who purchased more than 3 products

# %%
merged_data= pd.merge(customer, transaction, on='custno', how='inner')
customer_transaction_count = merged_data['custno'].value_counts()
customers_more_than_3_transaction = customer_transaction_count[customer_transaction_count > 3].index
customers_more_than_3_transaction_data = merged_data[merged_data['custno'].isin(customers_more_than_3_transaction)]
print("Customers from CSV_s1 who purchased more than 3 products:")
customers_more_than_3_transaction_data
# Out:
# Customers from CSV_s1 who purchased more than 3 products:
#      custno firstname lastname gender  age profession  contactNo  \
# 3         4    Alexis   Battle      M   27          S      71701
# 4         4    Alexis   Battle      M   27          S      71701
# 5         4    Alexis   Battle      M   27          S      71701
# 6         4    Alexis   Battle      M   27          S      71701
# 78       86    Bonnie   McCall      M   37          S      70907
# ..      ...       ...      ...    ...  ...        ...        ...
# 824     828   Katrina   Barber      M   47          S      61069
# 951     989    Ronald     Mayo      F   56          B      23161
# 952     989    Ronald     Mayo      F   56          B      23161
# 953     989    Ronald     Mayo      F   56          B      23161
# 954     989    Ronald     Mayo      F   56          B      23161
#
#                       emailId             city      state isActive  \
# ...

# %%
# Usecase-3 Display top 5 most demanded products from CSV_s1:

# %%
product_demand = transaction['productno'].value_counts().head(5)
get_data=pd.merge(product_demand,product,right_on="productno",left_index=True)
print("Top 5 most demanded products from CSV_s1: ")
get_data
# Out:
# Top 5 most demanded products from CSV_s1:
#      productno  productno_x  productno_y productName Description isActive  \
# 81          82            5           82   Product82  ignxxzodmc        Y
# 426        427            5          427  Product427  rnqzbzweys        Y
# 899        900            5          900  Product900  ouoolyahlh        N
# 767        768            5          768  Product768  hvfbltpjun        Y
# 848        849            4          849  Product849  qevomhstmc        Y
#
#              createdDate          UpdatedDate
# 81   2017-09-24 02:57:26  2017-10-18 12:12:38
# 426  2017-09-14 10:44:57  2017-10-18 12:12:38
# 899  2017-01-10 12:35:30  2017-10-18 12:12:39
# 767  2017-01-27 11:45:21  2017-10-18 12:12:39
# 848  2017-06-12 09:06:06  2017-10-18 12:12:39

# %%
# Usecase-4 Display top 5 transactions amount from CSV_s1:

# %%
trans_amt = transaction["amount"].sort_values(ascending=False).head(5)
trans_amt_data=pd.merge(trans_amt,transaction)
trans_amt_data4=pd.merge(trans_amt_data,customer)
print("Top 5 transactions amount from CSV_s1: ")
trans_amt_data4
# Out:
# Top 5 transactions amount from CSV_s1:
#    amount  txnno              txndate  custno  productno spendby firstname  \
# 0    4996    557  2017-10-18 12:31:46     670        509    Card     Vicki
# 1    4992    306  2017-10-18 12:31:46     448        427    Cash     Joyce
# 2    4981    575  2017-10-18 12:31:46     305        549    Card    Janice
# 3    4980    532  2017-10-18 12:31:46     230        658    Card      Jean
# 4    4966    233  2017-10-18 12:31:45     287        685    Card    Alissa
#
#     lastname gender  age profession  contactNo                 emailId  \
# 0      Frank      M   27          S      84305  jcolon28@everyma1l.net
# 1     Slater      M   57          S      47613   spittman@somema1l.biz
# 2  Valentine      F   62          B      23111       jglover@gma1l.biz
# 3  Singleton      M   64          S      30274      listwhat@gma1l.com
# 4        Roy      F   18          B      85584    bengland@yah00.co.uk
#
# ...

# %%
# Usecase-5 Display distinct professions from CSV_s1:

# %%
distinct= customer['profession'].unique()
print("Distinct professions from CSV_s1:",distinct)
# Out:
# Distinct professions from CSV_s1: ['B' 'S']

# %%
# Usecase-6 Display highest age in CSV_s1 customer’s dataset

# %%
age= customer["age"].max()
print("highest age in CSV_s1 customer’s dataset:",age)
# Out:
# highest age in CSV_s1 customer’s dataset: 64

# %%
# Usecase-7 Display custno, gender, age, profession, contactno, productno, productName,txndate, spendby, amount from CSV_s1 for custno = 923

# %%
a=pd.merge(customer,transaction)
data=pd.merge(a,product,right_on="productno",left_index=True)
specific_data= data[data["custno"]==923]
filter=specific_data[["custno","gender","age","profession", "contactNo", "productno","productName","txndate", "spendby", "amount"]]
filter
# Out:
#      custno gender  age profession  contactNo  productno productName  \
# 928     923      F   46          B      25436        929  Product929
# 929     923      F   46          B      25436        930  Product930
# 930     923      F   46          B      25436        931  Product931
#
#                  txndate spendby  amount
# 928  2017-10-18 12:31:45    Card    2559
# 929  2017-10-18 12:31:46    Card    2303
# 930  2017-10-18 12:31:46    Cash    4553

# %%
# Loading PSV (pipe separated values)


paths = 'customers (1).txt'
pipe_customer = pd.read_csv(paths, header=None,sep='|', names = ['custno','firstname','lastname','gender','age','profession','contactNo','emailId','city','state','isActive','createdDate','UpdatedDate'])
pipe_customer.to_csv(paths,index=False)

paths = 'products.txt'
pipe_product = pd.read_csv(paths, header=None,sep='|', names = ['productno', 'productName', 'Description', 'isActive', 'createdDate', 'UpdatedDate'])
pipe_product.to_csv(paths,  index=False)

paths = 'transactions.txt'
pipe_transaction = pd.read_csv(paths , header= None,sep='|', names = ['txnno','txndate','custno','amount','productno','spendby'])
pipe_transaction.to_csv(paths, index=False)

# %%
# Usecase-8 Load all three PSV (pipe separated values) dataset in Pandas Data frames and display first 5 records.

print(pipe_customer.head(5))

print(pipe_product.head(5))

print(pipe_transaction.head(5))

# %%
# Loading JSON datasets in Pandas Data frames:

json_customer=pd.read_json('customers.json',lines=True)

json_product=pd.read_json('products.json',lines=True)

json_transaction=pd.read_json('transactions.json',lines=True)

# %%
# Usecase-9 Load all three JSON datasets in Pandas Data frames and display first 5 records.

print(json_customer.head())

print(json_product.head())

print(json_transaction.head())

# %%
# Loading XML datasets in Pandas Data frames:

XML_customer=pd.read_xml('customers.xml',names = ['custno','firstname','lastname','gender','age','profession','contactNo','emailId','city','state','isActive','createdDate','UpdatedDate'])

XML_product=pd.read_xml('products.xml',names=['productno', 'productName', 'Description', 'isActive', 'createdDate', 'UpdatedDate'])

XML_transaction=pd.read_xml('transactions.xml',names=['txnno','txndate','custno','amount','productno','spendby'])

# %%
# Usecase-10 Load all three XML datasets in Pandas Data frames and display first 5 records:

print(XML_customer.head())

print(XML_product.head())

print(XML_transaction.head())
